# %%
import pandas as pd
import requests
import pickle
import config
import uuid
import sqlquerycmd as qcmd
from sqlcon import dbcon
import sqlcon as con
from sqlalchemy import create_engine

# %%
fct1_con = dbcon(config.fct1_user, config.fct1_password, config.fct1_host, config.fct1_dbname, config.driver)
con = create_engine(f'mssql+pyodbc://{config.fct1_user}:{config.fct1_password}@{config.fct1_host}/{config.fct1_dbname}?driver={config.driver}')
print(fct1_con)
print(con)
fct1_df = pd.read_sql(qcmd.select_top(100, "UUTResults"), con)

fct1_df.head()
# Out:
# Engine(mssql+pyodbc://sa:***@025A123FCTPCBA/A123_025A123FCT1?driver=ODBC+Driver+17+for+SQL+Server)
# Engine(mssql+pyodbc://sa:***@025A123FCTPCBA/A123_025A123FCT1?driver=ODBC+Driver+17+for+SQL+Server)
#    UUTResultsId         Station       Operator FamilyName        FixtureId  \
# 0             1  025A123FCTPCBA  Administrator    BMS 12V  3000.110.1028.1
# 1             2  025A123FCTPCBA  Administrator    BMS 12V  3000.110.1028.1
# 2             3  025A123FCTPCBA  Administrator    BMS 12V  3000.110.1028.1
# 3             4  025A123FCTPCBA  Administrator    BMS 12V  3000.110.1028.1
# 4             5  025A123FCTPCBA  Administrator    BMS 12V  3000.110.1028.1
#
#   FixtureSerialNumber ProjectRevision  ProjectReleased   VariantCode  \
# 0                0001              28            False  461023280103
# 1                0001              28            False  461023280103
# 2                0001              28            False  461023280103
# 3                0001              28            False  461023280103
# 4                0001              28            False  461023280103
#
#    VariantReleased  ...             SerialNumber            DateTime  \
# 0            False  ...  K01200400HW461023280103 2020-09-09 14:55:48
# 1            False  ...  K01201000FX461023280103 2020-09-09 14:55:32
# 2            False  ...  K01201000FX461023280103 2020-09-09 14:56:48
# 3            False  ...  K01203200CD461023280103 2020-09-09 14:58:06
# 4            False  ...  K01203200CD461023280103 2020-09-09 15:01:02
#
#         Date      Time StatusId FailureCode  \
# 0 2020-09-09  14:55:48        2         230
# 1 2020-09-09  14:55:32        2         310
# 2 2020-09-09  14:56:48        2         310
# 3 2020-09-09  14:58:06        2         320
# 4 2020-09-09  15:01:02        5           0
#
#                                   FailureDescription  ErrorCode  \
# 0  230: T.1 LIN Traffic Check\n650: Verify BMS is...          0
# 1  310: T.9 Voltage Calibration\n2630: Check Calc...          0
# 2  310: T.9 Voltage Calibration\n2630: Check Calc...          0
# 3  320: T.10 Current Calibration\n3820: DMM Calib...          0
# 4                                                             0
#
#   ErrorDescription  ExecutionTime
# 0                       21.322426
# 1                       53.754673
# 2                       51.867967
# 3                      129.649969
# 4                        1.403788
#
# [5 rows x 22 columns]

# %%
fct1_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   UUTResultsId         46 non-null     int64
#  1   Station              46 non-null     object
#  2   Operator             46 non-null     object
#  3   FamilyName           46 non-null     object
#  4   FixtureId            46 non-null     object
#  5   FixtureSerialNumber  46 non-null     object
#  6   ProjectRevision      46 non-null     object
#  7   ProjectReleased      46 non-null     bool
#  8   VariantCode          46 non-null     object
#  9   VariantReleased      46 non-null     bool
#  10  EC                   46 non-null     object
#  11  Socket               46 non-null     int64
#  12  SerialNumber         46 non-null     object
#  13  DateTime             46 non-null     datetime64[ns]
#  14  Date                 46 non-null     datetime64[ns]
#  15  Time                 46 non-null     object
#  16  StatusId             46 non-null     int64
#  17  FailureCode          46 non-null     int64
#  18  FailureDescription   46 non-null     object
#  19  ErrorCode            46 non-null     int64
#  20  ErrorDescription     46 non-null     object
#  21  ExecutionTime        46 non-null     float64
# dtypes: bool(2), datetime64[ns](2), float64(1), int64(5), object(12)
# memory usage: 7.4+ KB
